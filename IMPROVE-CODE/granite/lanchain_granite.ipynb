# %%
# https://developer.ibm.com/articles/awb-retrieval-augmented-generation-with-langchain-and-elastic-db/
#https://www.govinfo.gov/content/pkg/CREC-2024-03-07/html/CREC-2024-03-07-pt1-PgS2249-9.htm
# TO INSTALL ELASTIC: https://www.elastic.co/guide/en/elasticsearch/reference/7.17/brew.html

from langchain.vectorstores import ElasticsearchStore
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings

####### Load the document into  elastic store using hugging face embeddings as the embedding function. Which could be one time activity depending on the use-case.

loader = TextLoader("./state_of_the_union.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=500, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

embeddings = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2", model_kwargs={"device": "cpu"})
# Out:
# Created a chunk of size 1758, which is longer than the specified 500
# Created a chunk of size 6117, which is longer than the specified 500

# %%
db = ElasticsearchStore.from_documents(
    docs, embeddings, es_url="http://localhost:9200", index_name="test-basic",
)

db.client.indices.refresh(index="test-basic")
# Out:
# Error connecting to Elasticsearch: Connection error caused by: ConnectionError(Connection error caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x148864680>: Failed to establish a new connection: [Errno 61] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 db = ElasticsearchStore.from_documents(
#       2     docs, embeddings, es_url="http://localhost:9200", index_name="test-basic",
#       3 )
#       5 db.client.indices.refresh(index="test-basic")
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_community/vectorstores/elasticsearch.py:1249, in ElasticsearchStore.from_documents(cls, documents, embedding, bulk_kwargs, **kwargs)
#    1206 @classmethod
#    1207 def from_documents(
#    1208     cls,
#    (...)
#    1212     **kwargs: Any,
#    1213 ) -> "ElasticsearchStore":
#    1214     """Construct ElasticsearchStore wrapper from documents.
#    1215
#    1216     Example:
#    (...)
#    1246                     Elasticsearch bulk.
#    1247     """
# -> 1249     elasticsearchStore = ElasticsearchStore._create_cls_from_kwargs(
#    1250         embedding=embedding, **kwargs
#    1251     )
#    1252     # Encode the provided texts and add them to the newly created index.
#    1253     elasticsearchStore.add_documents(documents, bulk_kwargs=bulk_kwargs)
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_community/vectorstores/elasticsearch.py:1192, in ElasticsearchStore._create_cls_from_kwargs(embedding, **kwargs)
#    1189 if query_field is not None:
#    1190     optional_args["query_field"] = query_field
# -> 1192 return ElasticsearchStore(
#    1193     index_name=index_name,
#    1194     embedding=embedding,
#    1195     es_url=es_url,
#    1196     es_connection=es_connection,
#    1197     es_cloud_id=es_cloud_id,
#    1198     es_user=es_user,
#    1199     es_password=es_password,
#    1200     es_api_key=es_api_key,
#    1201     strategy=strategy,
#    1202     distance_strategy=distance_strategy,
#    1203     **optional_args,
#    1204 )
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_core/_api/deprecation.py:183, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     181     warned = True
#     182     emit_warning()
# --> 183 return wrapped(self, *args, **kwargs)
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_community/vectorstores/elasticsearch.py:548, in ElasticsearchStore.__init__(self, index_name, embedding, es_connection, es_url, es_cloud_id, es_user, es_api_key, es_password, vector_query_field, query_field, distance_strategy, strategy, es_params)
#     546     self.client = es_connection.options(headers=headers)
#     547 elif es_url is not None or es_cloud_id is not None:
# --> 548     self.client = ElasticsearchStore.connect_to_elasticsearch(
#     549         es_url=es_url,
#     550         username=es_user,
#     551         password=es_password,
#     552         cloud_id=es_cloud_id,
#     553         api_key=es_api_key,
#     554         es_params=es_params,
#     555     )
#     556 else:
#     557     raise ValueError(
#     558         """Either provide a pre-existing Elasticsearch connection, \
#     559         or valid credentials for creating a new connection."""
#     560     )
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_community/vectorstores/elasticsearch.py:616, in ElasticsearchStore.connect_to_elasticsearch(es_url, cloud_id, api_key, username, password, es_params)
#     614 except Exception as e:
#     615     logger.error(f"Error connecting to Elasticsearch: {e}")
# --> 616     raise e
#     618 return es_client
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/langchain_community/vectorstores/elasticsearch.py:613, in ElasticsearchStore.connect_to_elasticsearch(es_url, cloud_id, api_key, username, password, es_params)
#     608 es_client = elasticsearch.Elasticsearch(
#     609     **connection_params,
#     610     headers={"user-agent": ElasticsearchStore.get_user_agent()},
#     611 )
#     612 try:
# --> 613     es_client.info()
#     614 except Exception as e:
#     615     logger.error(f"Error connecting to Elasticsearch: {e}")
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elasticsearch/_sync/client/__init__.py:2460, in Elasticsearch.info(self, error_trace, filter_path, human, pretty)
#    2458     __query["pretty"] = pretty
#    2459 __headers = {"accept": "application/json"}
# -> 2460 return self.perform_request(  # type: ignore[return-value]
#    2461     "GET",
#    2462     __path,
#    2463     params=__query,
#    2464     headers=__headers,
#    2465     endpoint_id="info",
#    2466     path_parts=__path_parts,
#    2467 )
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)
#     337     )
#     338 ):
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)
#     357         )
#     358     )
#     360     if method != "HEAD":
#
# File ~/opt/anaconda3/envs/morgage/lib/python3.12/site-packages/elastic_transport/_node/_http_urllib3.py:202, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     194         err = ConnectionError(str(e), errors=(e,))
#     195     self._log_request(
#     196         method=method,
#     197         target=target,
#    (...)
#     200         exception=err,
#     201     )
# --> 202     raise err from None
#     204 meta = ApiResponseMeta(
#     205     node=self.config,
#     206     duration=duration,
#    (...)
#     209     headers=response_headers,
#     210 )
#     211 self._log_request(
#     212     method=method,
#     213     target=target,
#    (...)
#     217     response=data,
#     218 )
#
# ConnectionError: Connection error caused by: ConnectionError(Connection error caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x148864680>: Failed to establish a new connection: [Errno 61] Connection refused))

# %%
# !pip install elasticsearch
