# %% [markdown]
# # Comparison of cost and results for scrappers using AI
#
# - https://www.youtube.com/watch?v=QxHE4af5BQE
#
# - https://github.com/trancethehuman/ai-workshop-code/blob/main/Web_scraping_for_LLM_in_2024.ipynb

# %%
competitor_sites = [
    {
        "name": "Articulate 360 by Adobe",
        "url": "https://www.articulate.com/360/pricing/freelancers"
    },
    {
        "name": "7taps",
        "url": "https://www.7taps.com/pricing"
    },
    {
        "name": "Mindsmith AI",
        "url": "https://www.mindsmith.ai/pricing"
    },
    {
        "name": "Cards-microlearning",
        "url": "https://www.cards-microlearning.com/en/tarifs"
    },
]

# %% [markdown]
# !pip install tiktoken --quiet

# %%
import tiktoken

def count_tokens(input_string: str) -> int:
    tokenizer = tiktoken.get_encoding("cl100k_base")

    tokens = tokenizer.encode(input_string)

    return len(tokens)

def calculate_cost(input_string: str, cost_per_million_tokens: float = 5) -> float:
    num_tokens = count_tokens(input_string)

    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens

    return total_cost

# Example usage:
input_string = "What's the difference between beer nuts and deer nuts? Beer nuts are about 5 dollars. Deer nuts are just under a buck."
cost = calculate_cost(input_string)
print(f"The total cost for using gpt-4o is: $US {cost:.6f}")
# Out:
# The total cost for using gpt-4o is: $US 0.000135

# %% [markdown]
# pip install prettytable tqdm --quiet

# %%
from typing import List, Callable, Dict
from prettytable import PrettyTable, ALL
from tqdm import tqdm

def view_scraped_content(scrape_url_functions: List[Dict[str, Callable[[str], str]]], sites_list: List[Dict[str, str]], characters_to_display: int = 500, table_max_width: int = 50) -> List[Dict[str, str]]:
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    cost_table = PrettyTable()
    cost_table.field_names = cost_table_headers

    scraped_data = []

    for site in sites_list:
        content_row = [site['name']]
        cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                try:
                    content = scrape_function['function'](site['url'])
                    content_snippet = content[:characters_to_display]
                    content_row.append(content_snippet)

                    cost = calculate_cost(content)
                    cost_row.append(f"${cost:.6f}")

                    site_data["sites"].append({"name": function_name, "content": content})
                except Exception as e:
                    error_message = f"Error: {str(e)}"
                    content_row.append(error_message)
                    cost_row.append("Error")

                    site_data["sites"].append({"name": function_name, "content": error_message})
                    continue

        content_table.add_row(content_row)
        cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = ALL

    cost_table.max_width = table_max_width
    cost_table.hrules = ALL

    print("Content Table:")
    print(content_table)

    print("\nCost Table:\nThis is how much it would cost to use gpt-4o to parse this content for extraction.")
    print(cost_table)

    return scraped_data

# %%
# Beautiful Soup utility functions
import requests
from bs4 import BeautifulSoup

def beautiful_soup_scrape_url(url: str):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    return str(soup)

# %%
import requests
def scrape_jina_ai(url: str) -> str:
  response = requests.get("https://r.jina.ai/" + url)
  return response.text

# %% [markdown]
# pip install firecrawl-py --quiet

# %%
import firecrawl
import getpass
import sys, os
import requests
sys.path.append(os.path.abspath(os.path.join('..', 'secret')))
from secret_info import fire_crawl 

FIRECRAWL_API_KEY = fire_crawl
def scrape_firecrawl(url: str):
    app = firecrawl.FirecrawlApp(api_key=FIRECRAWL_API_KEY)
    scraped_data = app.scrape_url(url)["markdown"]
    return scraped_data

# %%
list_of_scraper_functions = [
      {"name": "Beautiful Soup", "function": beautiful_soup_scrape_url},
      {"name": "Firecrawl", "function": scrape_firecrawl},
      {"name": "Jina AI", "function": scrape_jina_ai}
      ]

all_content = view_scraped_content(list_of_scraper_functions, competitor_sites, 700, 20)
# Out:
# Processing site Articulate 360 by Adobe using Beautiful Soup: 100%|██████████| 1/1 [00:00<00:00,  3.01it/s]
# Processing site Articulate 360 by Adobe using Firecrawl: 100%|██████████| 1/1 [00:04<00:00,  4.77s/it]
# Processing site Articulate 360 by Adobe using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# Processing site 7taps using Beautiful Soup: 100%|██████████| 1/1 [00:00<00:00,  1.76it/s]
# Processing site 7taps using Firecrawl: 100%|██████████| 1/1 [00:03<00:00,  3.14s/it]
# Processing site 7taps using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.13s/it]
# Processing site Mindsmith AI using Beautiful Soup: 100%|██████████| 1/1 [00:01<00:00,  1.09s/it]
# Processing site Mindsmith AI using Firecrawl: 100%|██████████| 1/1 [00:03<00:00,  3.57s/it]
# Processing site Mindsmith AI using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]
# Processing site Cards-microlearning using Beautiful Soup: 100%|██████████| 1/1 [00:00<00:00,  1.62it/s]
# Processing site Cards-microlearning using Firecrawl: 100%|██████████| 1/1 [00:04<00:00,  4.35s/it]
# Processing site Cards-microlearning using Jina AI: 100%|██████████| 1/1 [00:01<00:00,  1.00s/it]
# Content Table:
# +----------------------+------------------------+----------------------+----------------------+
# |      Site Name       | Beautiful Soup content |  Firecrawl content   |   Jina AI content    |
# +----------------------+------------------------+----------------------+----------------------+
# |  Articulate 360 by   |         <html>         |    [Skip to main     |  Title: Freelancer   |
# |        Adobe         | <head><title>403 Forbi |  content](#content)  |     Pricing for      |
# |                      |  dden</title></head>   |                      |   Articulate 360 -   |
# |                      |         <body>         | [![Articulate](https | Everything You Need  |
# |                      | <center><h1>403 Forbid | ://www.articulate.co | to Create E‑Learning |
# |                      |   den</h1></center>    | m/wp-content/uploads |                      |
# |                      | <hr/><center>nginx</ce | /2023/06/articulate- | URL Source: https:// |
# |                      |         nter>          | logo.svg)](https://w | www.articulate.com/3 |
# |                      |        </body>         | ww.articulate.com/)  | 60/pricing/freelance |
# |                      |        </html>         |                      |          rs          |
# |                      |                        | *   [Products](https |                      |
# |                      |                        | ://www.articulate.co |  Markdown Content:   |
# |                      |                        |       m/360/)        |  Our personal plan   |
# |                      |                        |     *   [Articulate  | includes everything  |
# |                      |                        | 360 Platform](https: |  you need to create  |
# |                      |                        | //www.articulate.com |  e-learning on your  |
# |                      |                        |        /360/)        |         own.         |
# |                      |                        |                      |                      |
# |                      |                        |     *   [Rise 360](h |  Articulate 360 for  |
# |                      |                        | ttps://www.articulat |     Freelancers      |
# |                      |                        |   e.com/360/rise/)   | -------------------- |
# |                      |                        |                      |      ----------      |
# |                      |                        |     *   [Storyline 3 |                      |
# |                      |                        | 60](https://www.arti | ![Image 1](https://w |
# |                      |                        | culate.com/360/story | ww.articulate.com/wp |
# |                      |                        |        line/)        | -content/uploads/202 |
# |                      |                        |                      |    3/10/pricing-     |
# |                      |                        |     *   [Reach 360]( |      illo.png)       |
# |                      |                        | https://www.articula |                      |
# |                      |                        |  te.com/360/reach/)  | [Personal Plan](http |
# |                      |                        |                      | s://www.articulate.c |
# |                      |                        |     *   [Articulate  |       om/360/)       |
# |                      |                        | 360 Teams](https://w | -------------------- |
# |                      |                        | ww.articulate.com/36 | -------------------- |
# |                      |                        |      0/teams/)       |       --------       |
# |                      |                        |                      |                      |
# |                      |                        | *   [Pricing](https: |    **Perfect for     |
# |                      |                        | //www.articulate.com |     individuals.     |
# |                      |                        |    /360/pricing/)    | Everything you need  |
# |                      |                        |     *   [Pricing Ove |      to create       |
# |                      |                        | rview](https://www.a |    e-learning.**     |
# |                      |                        | rticulate.com/360/pr |                      |
# |                      |                        |       icing/)        |  1,199$USDper user,  |
# |                      |                        |                      |       annually       |
# |                      |                        |                      |   For individuals    |
# |                      |                        |                      |                      |
# |                      |                        |                      |    All prices USD    |
# |                      |                        |                      |                      |
# |                      |                        |                      |     ### Features     |
# |                      |                        |                      |                      |
# |                      |                        |                      |     #### Course      |
# |                      |                        |                      |    Authoring Apps    |
# |                      |                        |                      |                      |
# |                      |                        |                      | Rise 360, Storyline  |
# |                      |                        |                      |         360,         |
# +----------------------+------------------------+----------------------+----------------------+
# |        7taps         |    <!DOCTYPE html>     |  [MicrolearningCONF  | Title: 7taps pricing |
# |                      |  <!-- Last Published:  | ep.15  |  Book a FRE |        plans         |
# |                      |    Fri Aug 09 2024     | E seat →](https://ww |                      |
# |                      |   18:10:12 GMT+0000    | w.microlearningconf. | URL Source: https:// |
# |                      | (Coordinated Universal |        com/)         | www.7taps.com/pricin |
# |                      |  Time) --><html data-  |                      |          g           |
# |                      |          wf-           | [![](https://cdn.pro |                      |
# |                      | domain="www.7taps.com" | d.website-files.com/ |  Markdown Content:   |
# |                      | data-wf-page="6210eab9 | 6040dae83112172e5cc9 |     How is 7taps     |
# |                      |   77ab3b4dedf4d5f1"    | b16f/65c262c6c8b053c | different from other |
# |                      | data-wf-site="6040dae8 | 756732bba_Frame.webp |    microlearning     |
# |                      |   3112172e5cc9b16f"    | )![](https://cdn.pro |       vendors?       |
# |                      | lang="en"><head><meta  | d.website-files.com/ |                      |
# |                      |     charset="utf-      | 6040dae83112172e5cc9 |         add          |
# |                      |    8"/><title>7taps    | b16f/65c262c6c8b053c |                      |
# |                      |        pricing         | 756732bba_Frame.webp | 7taps pioneered the  |
# |                      |   plans</title><meta   | )![](https://cdn.pro | concept of effective |
# |                      | content="See detailed  | d.website-files.com/ |    microlearning     |
# |                      |   pricing plans for    | 6040dae83112172e5cc9 |  implementation in   |
# |                      |  7taps Microlearning.  | b16f/65c262c6c8b053c |  the enterprise L&D  |
# |                      |  Enterprise plan free  | 756732bba_Frame.webp | landscape four years |
# |                      |  trial available. Try  | )![](https://cdn.pro | ago, and we continue |
# |                      |    #1 microlearning    | d.website-files.com/ |   to dominate this   |
# |                      | platform today!" name= | 6040dae83112172e5cc9 | space. Unlike other  |
# |                      |  "description"/><meta  | b16f/65c262c6c8b053c |  vendors who might   |
# |                      | content="7taps pricing | 756732bba_Frame.webp |   hand you a tool    |
# |                      | plans" property="og:ti | )![](https://cdn.pro |  without a roadmap,  |
# |                      |      tle"/><meta       | d.website-files.com/ | we're here to guide  |
# |                      | content="See detailed  | 6040dae83112172e5cc9 |   you through the    |
# |                      |   pricing plans for    | b16f/65c262c6c8b053c |     intricacies,     |
# |                      |  7taps Microlearning.  | 756732bba_Frame.webp | ensuring you harness |
# |                      |  Enterprise plan free  | )![](https://cdn.pro |  the true potential  |
# |                      |  trial available. Try  | d.website-files.com/ | of microlearning. We |
# |                      |    #1 microlearning    | 6040dae83112172e5cc9 |    uniquely offer    |
# |                      | platform today!" prope | b16f/65c262c6c8b053c |   lightning-fast,    |
# |                      | rty="og:description"/> | 756732bba_Frame.webp |     high-quality     |
# |                      |   <meta content="ht    |     )](/contest)     |    microlearning     |
# |                      |                        |                      |    creation that     |
# |                      |                        |                      |    enables you to    |
# |                      |                        |                      |     connect with     |
# |                      |                        |                      |  learners anywhere   |
# |                      |                        |                      |  through versatile   |
# |                      |                        |                      |   sharing options.   |
# |                      |                        |                      |   Moreover, 7taps'   |
# |                      |                        |                      | [science-driven meth |
# |                      |                        |                      | odology](https://www |
# |                      |                        |                      |         .7ta         |
# +----------------------+------------------------+----------------------+----------------------+
# |     Mindsmith AI     |    <!DOCTYPE html>     | [![](https://cdn.pro |    Title: Pricing    |
# |                      |   <!-- This site was   | d.website-files.com/ |                      |
# |                      |  created in Webflow.   | 63210902df3949e6e16c | URL Source: https:// |
# |                      |  https://webflow.com   | b030/64653794e115e4a | www.mindsmith.ai/pri |
# |                      |      --><!-- Last      | c4b553aa0_logo.svg)] |         cing         |
# |                      | Published: Thu Aug 08  |         (/)          |                      |
# |                      | 2024 07:38:20 GMT+0000 |                      |  Markdown Content:   |
# |                      | (Coordinated Universal | [Pricing](/pricing)  | ![Image 1](https://c |
# |                      |  Time) --><html data-  |   [About](/about)    | dn.prod.website-file |
# |                      | wf-domain="www.mindsmi | [Book a Demo](https: | s.com/63210902df3949 |
# |                      | th.ai" data-wf-page="6 | //app.apollo.io/#/me | e6e16cb030/65675d24c |
# |                      | 54aa6a027f185dda8fec0d | et/ethan_webb_63c/de | 236608822d95212_Feat |
# |                      | 0" data-wf-site="63210 |         mo)          | ured%20icon%20Free.p |
# |                      |  902df3949e6e16cb030"  | [Partner](/partners) |         ng)          |
# |                      | lang="en"><head><meta  |    [Blog](/blog)     |                      |
# |                      |     charset="utf-      |                      |      #### Free       |
# |                      | 8"/><title>Pricing</ti | [Log in](https://app |                      |
# |                      |       tle><meta        |   .mindsmith.ai/)    |          $0          |
# |                      |  content="Pricing and  |                      |          --          |
# |                      | plans for teams of all | [Get Started](https: |                      |
# |                      | sizes, from individual | //app.mindsmith.ai/s |  Try out Mindsmith   |
# |                      | creators to eLearning  |        ignup)        |       for free       |
# |                      | teams. Start for free  |                      |                      |
# |                      |   or talk to a real    | [Sign Up](https://ap | [Create an account]( |
# |                      | person to learn more!" | p.mindsmith.ai/signu | https://app.mindsmit |
# |                      | name="description"/><m |          p)          |     h.ai/signup)     |
# |                      | eta content="Pricing"  |                      |                      |
# |                      | property="og:title"/>< | Plans for all sizes  | ![Image 2](https://c |
# |                      | meta content="Pricing  | ===================  | dn.prod.website-file |
# |                      | and plans for teams of |                      | s.com/63210902df3949 |
# |                      |    all sizes, from     | We provide discounts | e6e16cb030/656765814 |
# |                      | individual creators to |   to educators and   | 6e245f22fece858_Chec |
# |                      | eLearning teams. Start |      non-profit      |    k%20icon.png)     |
# |                      | for free or talk to a  |    organizations.    |                      |
# |                      |           r            | [Contact Us.](mailto |   Create unlimited   |
# |                      |                        | :ethan@mindsmith.ai? |       lessons        |
# |                      |                        | subject=Non-profit%2 |                      |
# |                      |                        | 0%26%20Education%20d | ![Image 3](https://c |
# |                      |                        |      iscounts)       | dn.prod.website-file |
# |                      |                        |                      | s.com/63210902df3949 |
# |                      |                        | [Monthly](#w-tabs-0- | e6e16cb030/656765814 |
# |                      |                        |    data-w-pane-0)    | 6e245f22fece858_Chec |
# |                      |                        |       [Annual\       |    k%20icon.png)     |
# |                      |                        |          \           |                      |
# |                      |                        |         Save         |  Two active shared   |
# |                      |                        | 20%](#w-tabs-0-data- |       lessons        |
# |                      |                        |      w-pane-1)       |                      |
# |                      |                        |                      | ![Image 4](https://c |
# |                      |                        | ![](https://cdn.prod | dn.prod.website-file |
# |                      |                        | .website-files.com/6 | s.com/63210902df3949 |
# |                      |                        |      3210902df3      | e6e16cb030/656765814 |
# |                      |                        |                      | 6e245f22fece858_Chec |
# |                      |                        |                      |     k%20icon.png     |
# +----------------------+------------------------+----------------------+----------------------+
# | Cards-microlearning  |    <!DOCTYPE html>     | [![Logo Cards micro- |    Title: Micro-     |
# |                      |  <!-- Last Published:  | learning](https://cd | learning cards from  |
# |                      |    Thu Aug 08 2024     | n.prod.website-files | €89 | IA | Learning  |
# |                      |   15:42:46 GMT+0000    | .com/642b30c7daf3c91 |       Routine®       |
# |                      | (Coordinated Universal | 85c06eaca/642b311ae5 |                      |
# |                      |  Time) --><html data-  | 7799309b8fc2df_Logo- |     URL Source:      |
# |                      | wf-domain="www.cards-  | Cards-Horizontal_Noi | https://www.cards-mi |
# |                      |   microlearning.com"   |     r.png)](/en)     | crolearning.com/en/t |
# |                      | data-wf-page="6446e0b1 |                      |        arifs         |
# |                      |   2b3fc3ef452f4a94"    |       Platform       |                      |
# |                      | data-wf-site="642b30c7 |                      |  Markdown Content:   |
# |                      |   daf3c9185c06eaca"    | [Functionalities](/e | Micro-learning cards |
# |                      | lang="fr"><head><meta  |  n/plateforme-lms-   |   from €89 | IA |    |
# |                      |     charset="utf-      |    microlearning)    |  Learning Routine®   |
# |                      |   8"/><title>Micro-    |      [Authoring      |   ===============    |
# |                      |  learning cards from   |   tool](/en/outil-   |                      |
# |                      |  €89 | IA | Learning   |       auteur)        |                      |
# |                      | Routine®</title><link  |   [MAY ✨](/en/ia)   |   [![Image 1: Logo   |
# |                      | href="https://www.card | [Learning Routine®]( | Cards micro-learning |
# |                      | s-microlearning.com/ta |    /en/learning-     | ](https://cdn.prod.w |
# |                      |         rifs"          |       routine)       | ebsite-files.com/642 |
# |                      |  hreflang="x-default"  | [Microsoft Teams](/e | b30c7daf3c9185c06eac |
# |                      | rel="alternate"/><link |    n/integration-    | a/642b311ae57799309b |
# |                      | href="https://www.card |   microsoft-teams)   | 8fc2df_Logo-Cards-Ho |
# |                      | s-microlearning.com/ta |                      | rizontal_Noir.png)]( |
# |                      | rifs" hreflang="fr-FR" |       Use case       | https://www.cards-mi |
# |                      | rel="alternate"/><link |                      | crolearning.com/en)  |
# |                      | href="https://www.card | [Onboarding](/en/lp/ |                      |
# |                      | s-microlearning.com/en |  formulaire-acces)   |       Platform       |
# |                      | /tarifs" hreflang="en" | [Mobile Learning](/e |                      |
# |                      | rel="alternate"/><meta |   n/lp/formulaire-   | [Functionalities](ht |
# |                      |  content="Discover 3   |        acces)        | tps://www.cards-micr |
# |                      |     offers to take     | [Change Management]( | olearning.com/en/pla |
# |                      |   advantage of Cards   |  /en/lp/formulaire-  | teforme-lms-microlea |
# |                      |  micro-learning in a   |        acces)        | rning)[Authoring too |
# |                      |          100%          | [Standards/Complianc | l](https://www.cards |
# |                      |                        | e](/en/lp/formulaire | -microlearning.com/e |
# |                      |                        |       -acces)        | n/outil-auteur)[MAY  |
# |                      |                        | [Lifelong Learning]( | ✨](https://www.cards |
# |                      |                        |  /en/lp/formulaire-  | -microlearning.com/e |
# |                      |                        |        acces)        | n/ia)[Learning Routi |
# |                      |                        | [Future of Work](/en | ne®](https://www.car |
# |                      |                        |   /lp/formulaire-    | ds-microlearning.com |
# |                      |                        |        acces)        |  /en/learning-rout   |
# |                      |                        |                      |                      |
# |                      |                        | [Pricing](/en/tarifs |                      |
# |                      |                        |          )           |                      |
# |                      |                        |                      |                      |
# |                      |                        |      Resources       |                      |
# |                      |                        |                      |                      |
# |                      |                        | [Integrations](/en/r |                      |
# |                      |                        |    essources/int     |                      |
# +----------------------+------------------------+----------------------+----------------------+
#
# Cost Table:
# This is how much it would cost to use gpt-4o to parse this content for extraction.
# +----------------------+---------------------+----------------+--------------+
# |      Site Name       | Beautiful Soup cost | Firecrawl cost | Jina AI cost |
# +----------------------+---------------------+----------------+--------------+
# |  Articulate 360 by   |      $0.000210      |   $0.021165    |  $0.008025   |
# |        Adobe         |                     |                |              |
# +----------------------+---------------------+----------------+--------------+
# |        7taps         |      $0.085095      |   $0.017910    |  $0.005745   |
# +----------------------+---------------------+----------------+--------------+
# |     Mindsmith AI     |      $0.205210      |   $0.022355    |  $0.018455   |
# +----------------------+---------------------+----------------+--------------+
# | Cards-microlearning  |      $0.147105      |   $0.035240    |  $0.038655   |
# +----------------------+---------------------+----------------+--------------+
